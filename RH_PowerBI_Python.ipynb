# %%
# Versão da linguagem Python
from platform import python_version
print("Versão da linguagem Python usada neste jupyter notebook: ",python_version())
# Out:
# Versão da linguagem Python usada neste jupyter notebook:  3.9.7

# %%
# Instala o pacote watermark
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook
# !pip install -q -U watermark
# Out:
# WARNING: You are using pip version 21.2.3; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\alverindo.junior\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\ALVERI~1.JUN\AppData\Local\Temp/ipykernel_6200/2987733189.py in <module>
#       6 import seaborn as sns
#       7 import warnings
# ----> 8 warnings.filter.warnings("ignore", category = FutureWarning)
#
# AttributeError: module 'warnings' has no attribute 'filter'

# %%
# Versões dos pacotes utilizados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy" --iversions
# Out:
# Author: Data Science Academy
#
# pandas    : 1.3.0
# matplotlib: 3.4.2
# numpy     : 1.19.5
# seaborn   : 0.11.2

# %%
dataset = pd.read_csv('dadosRH_modificado.csv')
dataset.head()
# Out:
#    id_funcionario departmento    regiao               educacao genero  \
# 0           65438   Marketing   Sudeste  Mestrado ou Doutorado      F
# 1           65141   Logistica  Nordeste               Superior      M
# 2            7513   Marketing   Sudeste               Superior      M
# 3            2542   Marketing     Norte               Superior      M
# 4           48945  Tecnologia  Nordeste               Superior      M
#
#   canal_recrutamento  numero_treinamentos  idade  aval_ano_anterior  \
# 0        Outsourcing                    1     35                5.0
# 1              Outro                    1     30                5.0
# 2        Outsourcing                    1     34                3.0
# 3              Outro                    2     39                1.0
# 4              Outro                    1     45                3.0
#
#    tempo_servico  promovido
# 0              8          0
# 1              4          0
# 2              7          0
# ...

# %%
# Pergunta 01: Qual a correlação entre os atributos dos funcionários?
import matplotlib.pyplot as plt
import seaborn as sns
corr = dataset.corr()
sns.heatmap(corr, cmap = "YlOrRd", linewidths = 0.1)
plt.show()

# %%
# Pergunta 02: Qual o tempo de serviço da maioria dos funcionarios?
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(dataset['tempo_servico'], color = 'green')
plt.title('Distribuição do tempo de serviço dos funcionarios', fontsize = 15)
plt.xlabel('Tempo de serviço em anos', fontsize = 15)
plt.ylabel('Total')
plt.show()
# Out:
# c:\users\alverindo.junior\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Pergunta 03: Qual avaliação do ano anterior foi mais comum?
import matplotlib.pyplot as plt
import seaborn as sns
dataset['aval_ano_anterior'].value_counts().sort_values().plot.bar(color = 'blue', figsize = (10,5))
plt.title('Distribuição da Avaliação do Ano Anterior dos Funcionários', fontsize = 15)
plt.xlabel('Avaliações', fontsize = 15)
plt.ylabel('Total')
plt.show()

# %%
# Pergunta 04: Qual a distribuição das idades dos funcionários
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(dataset['idade'], color = 'magenta')
plt.title('Distribuição da Idade dos funcionários', fontsize = 15)
plt.xlabel('Idade', fontsize = 15)
plt.ylabel('Total')
plt.show()

# %%
# Pergunta 05: Qual o numero de treinamento mais frequente?
import matplotlib.pyplot as plt
import seaborn as sns
sns.violinplot(dataset['numero_treinamentos'], color = 'red')
plt.title('Número de Treinamentos Feitos pelos Funcionários', fontsize = 15)
plt.xlabel('Número de Treinamentos', fontsize=15)
plt.ylabel('Frequência')
plt.show()

# %%
# Pergunta 06: Qual a proporção dos funcionários por canal de recrutamento?
import matplotlib.pyplot as plt
import seaborn as sns
dataset['canal_recrutamento'].value_counts()
fatias = [55375, 42358, 2547]
labels = "Outro", "Outsourcing", "Indicação"
colors = ['purple', 'lime', 'yellow']
explode = [0,0,0]
plt.pie(fatias, labels = labels, colors = colors, explode = explode, shadow = True, autopct = '%.2f%%')
plt.title('Percentual de Funcionários Por Canal de Recrutamento',fontsize =15)
plt.axis('off')
plt.show()

# %%
# Pergunta 07: Qual a relação entre a promoção e a avaliação do ano anterior
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.crosstab(dataset['aval_ano_anterior'],dataset['promovido'])
data.div(data.sum(1).astype(float), axis =0).plot(kind = 'bar',
                                                 stacked = True,
                                                 figsize = (16,9),
                                                 color = ['blue','magenta'])
plt.title('Relação entre Avaliação do Ano Anterior e a Promoção', fontsize = 15)
plt.xlabel('Avaliação do Ano Anterior', fontsize = 15)
plt.legend()
plt.show()
